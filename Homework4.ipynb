# %% [markdown]
# ### <font color='#cb4154'> CS6375: Machine Learning (Spring '19) </font>
# _**Student**: Joel Yin_ <br>
# _**Instructor**: Gautam Kunapuli_ <br>
# _**Due**: In class, **April 15 (Monday)**_
#
# ---
#
# # **_Homework 4_**

# %% [markdown]
# ## Overview
#
# In this homework, I have implemented boosting and bagging ensemble methods with the base learner as a modified ID3 algorithm for generating decision trees. This report will compare my implementation with SciKit Learn's implementation of ensemble methods using decision trees.

# %% [markdown]
# ## Summary of Differences
#
# My implementation of bagging worked well, having comparable performance. It did really for small depths and ensemble size. The confusion matrices show that my bagging ensemble implementation worked very well.
#
# However, my implementation of boosting performed markedly worse compared to sci-kit learn's implementation. My boosting ensemble is not flawed per se, but is the result of having a very selective splitting conditions. However, if on the other hand, split trees/B-trees was used instead of a binary tree, I believe that our accuracy would improve markedly, as we would then be able to take into account more mutual information when splitting.

# %% [markdown]
# ## Training and Analysis - Mushroom Data Set

# %%
# %run decision_tree.py

# %% [markdown]
# ### Bagging
# #### Confusion Matrices for Bagging
#
# <table style="border: 1px solid black">
#     <tr style="border: 1px solid black">
#         <th style="border: 1px solid black">Hyper Parameters</th>
#         <th style="border: 1px solid black">My Bagging Ensemble Confusion Matrix</th>
#         <th style="border: 1px solid black">Sci-Kit's Ensemble Confusion Matrix</th>
#     </tr>
#     <tr style="border: 1px solid black">
#         <td style="border: 1px solid black">
#             <p>Max Depth: 3</p>
#             <p>Bag Size: 5</p>
#         </td>
#         <td style="border: 1px solid black">
#             <table style="border: 1px solid black">
#                 <tr>
#                     <td style="border: 1px solid black">
#                         TP: {{ print(my_bagging_confusion_matrices[(3, 5)][1, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         FN: {{ print(my_bagging_confusion_matrices[(3, 5)][1, 0]) }}
#                     </td>
#                 </tr>
#                 <tr>
#                     <td style="border: 1px solid black">
#                         FP: {{ print(my_bagging_confusion_matrices[(3, 5)][0, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         TN: {{ print(my_bagging_confusion_matrices[(3, 5)][0, 0]) }}
#                     </td>
#                 </tr>
#             </table>
#             <p>Accuracy: {{ my_bagging_accuracies[(3, 5)] }}</p>
#             <p>Precision: {{ my_bagging_precisions[(3, 5)] }}</p>
#             <p>Recall: {{ my_bagging_recalls[(3, 5)] }}</p>
#         </td>
#         <td style="border: 1px solid black">
#             <table style="border: 1px solid black">
#                 <tr>
#                     <td style="border: 1px solid black">
#                         TP: {{ print(sk_bagging_confusion_matrices[(3, 5)][1, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         FN: {{ print(sk_bagging_confusion_matrices[(3, 5)][1, 0]) }}
#                     </td>
#                 </tr>
#                 <tr>
#                     <td style="border: 1px solid black">
#                         FP: {{ print(sk_bagging_confusion_matrices[(3, 5)][0, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         TN: {{ print(sk_bagging_confusion_matrices[(3, 5)][0, 0]) }}
#                     </td>
#                 </tr>
#             </table>
#             <p>Accuracy: {{ sk_bagging_accuracies[(3, 5)] }}</p>
#             <p>Precision: {{ sk_bagging_precisions[(3, 5)] }}</p>
#             <p>Recall: {{ sk_bagging_recalls[(3, 5)] }}</p>
#         </td>
#     </tr>
#     <tr style="border: 1px solid black">
#         <td style="border: 1px solid black">
#             <p>Max Depth: 3</p>
#             <p>Bag Size: 10</p>
#         </td>
#         <td style="border: 1px solid black">
#             <table style="border: 1px solid black">
#                 <tr>
#                     <td style="border: 1px solid black">
#                         TP: {{ print(my_bagging_confusion_matrices[(3, 10)][1, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         FN: {{ print(my_bagging_confusion_matrices[(3, 10)][1, 0]) }}
#                     </td>
#                 </tr>
#                 <tr>
#                     <td style="border: 1px solid black">
#                         FP: {{ print(my_bagging_confusion_matrices[(3, 10)][0, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         TN: {{ print(my_bagging_confusion_matrices[(3, 10)][0, 0]) }}
#                     </td>
#                 </tr>
#             </table>
#             <p>Accuracy: {{ my_bagging_accuracies[(3, 10)] }}</p>
#             <p>Precision: {{ my_bagging_precisions[(3, 10)] }}</p>
#             <p>Recall: {{ my_bagging_recalls[(3, 10)] }}</p>
#         </td>
#         <td style="border: 1px solid black">
#             <table style="border: 1px solid black">
#                 <tr>
#                     <td style="border: 1px solid black">
#                         TP: {{ print(sk_bagging_confusion_matrices[(3, 10)][1, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         FN: {{ print(sk_bagging_confusion_matrices[(3, 10)][1, 0]) }}
#                     </td>
#                 </tr>
#                 <tr>
#                     <td style="border: 1px solid black">
#                         FP: {{ print(sk_bagging_confusion_matrices[(3, 10)][0, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         TN: {{ print(sk_bagging_confusion_matrices[(3, 10)][0, 0]) }}
#                     </td>
#                 </tr>
#             </table>
#             <p>Accuracy: {{ sk_bagging_accuracies[(3, 10)] }}</p>
#             <p>Precision: {{ sk_bagging_precisions[(3, 10)] }}</p>
#             <p>Recall: {{ sk_bagging_recalls[(3, 10)] }}</p>
#         </td>
#     </tr>
#     <tr style="border: 1px solid black">
#         <td style="border: 1px solid black">
#             <p>Max Depth: 5</p>
#             <p>Bag Size: 5</p>
#         </td>
#         <td style="border: 1px solid black">
#             <table style="border: 1px solid black">
#                 <tr>
#                     <td style="border: 1px solid black">
#                         TP: {{ print(my_bagging_confusion_matrices[(5, 5)][1, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         FN: {{ print(my_bagging_confusion_matrices[(5, 5)][1, 0]) }}
#                     </td>
#                 </tr>
#                 <tr>
#                     <td style="border: 1px solid black">
#                         FP: {{ print(my_bagging_confusion_matrices[(5, 5)][0, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         TN: {{ print(my_bagging_confusion_matrices[(5, 5)][0, 0]) }}
#                     </td>
#                 </tr>
#             </table>
#             <p>Accuracy: {{ my_bagging_accuracies[(5, 5)] }}</p>
#             <p>Precision: {{ my_bagging_precisions[(5, 5)] }}</p>
#             <p>Recall: {{ my_bagging_recalls[(5, 5)] }}</p>
#         </td>
#         <td style="border: 1px solid black">
#             <table style="border: 1px solid black">
#                 <tr>
#                     <td style="border: 1px solid black">
#                         TP: {{ print(sk_bagging_confusion_matrices[(5, 5)][1, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         FN: {{ print(sk_bagging_confusion_matrices[(5, 5)][1, 0]) }}
#                     </td>
#                 </tr>
#                 <tr>
#                     <td style="border: 1px solid black">
#                         FP: {{ print(sk_bagging_confusion_matrices[(5, 5)][0, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         TN: {{ print(sk_bagging_confusion_matrices[(5, 5)][0, 0]) }}
#                     </td>
#                 </tr>
#             </table>
#             <p>Accuracy: {{ sk_bagging_accuracies[(5, 5)] }}</p>
#             <p>Precision: {{ sk_bagging_precisions[(5, 5)] }}</p>
#             <p>Recall: {{ sk_bagging_recalls[(5, 5)] }}</p>
#         </td>
#     </tr>
#     <tr style="border: 1px solid black">
#         <td style="border: 1px solid black">
#             <p>Max Depth: 5</p>
#             <p>Bag Size: 10</p>
#         </td>
#         <td style="border: 1px solid black">
#             <table style="border: 1px solid black">
#                 <tr>
#                     <td style="border: 1px solid black">
#                         TP: {{ print(my_bagging_confusion_matrices[(5, 10)][1, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         FN: {{ print(my_bagging_confusion_matrices[(5, 10)][1, 0]) }}
#                     </td>
#                 </tr>
#                 <tr>
#                     <td style="border: 1px solid black">
#                         FP: {{ print(my_bagging_confusion_matrices[(5, 10)][0, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         TN: {{ print(my_bagging_confusion_matrices[(5, 10)][0, 0]) }}
#                     </td>
#                 </tr>
#             </table>
#             <p>Accuracy: {{ my_bagging_accuracies[(5, 10)] }}</p>
#             <p>Precision: {{ my_bagging_precisions[(5, 10)] }}</p>
#             <p>Recall: {{ my_bagging_recalls[(5, 10)] }}</p>
#         </td>
#         <td style="border: 1px solid black">
#             <table style="border: 1px solid black">
#                 <tr>
#                     <td style="border: 1px solid black">
#                         TP: {{ print(sk_bagging_confusion_matrices[(5, 10)][1, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         FN: {{ print(sk_bagging_confusion_matrices[(5, 10)][1, 0]) }}
#                     </td>
#                 </tr>
#                 <tr>
#                     <td style="border: 1px solid black">
#                         FP: {{ print(sk_bagging_confusion_matrices[(5, 10)][0, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         TN: {{ print(sk_bagging_confusion_matrices[(5, 10)][0, 0]) }}
#                     </td>
#                 </tr>
#             </table>
#             <p>Accuracy: {{ sk_bagging_accuracies[(5, 10)] }}</p>
#             <p>Precision: {{ sk_bagging_precisions[(5, 10)] }}</p>
#             <p>Recall: {{ sk_bagging_recalls[(5, 10)] }}</p>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Boosting
# #### Confusion Matrices for Boosting
#
# <table style="border: 1px solid black">
#     <tr style="border: 1px solid black">
#         <th style="border: 1px solid black">Hyper Parameters</th>
#         <th style="border: 1px solid black">My Bagging Ensemble Confusion Matrix</th>
#         <th style="border: 1px solid black">Sci-Kit's Ensemble Confusion Matrix</th>
#     </tr>
#     <tr style="border: 1px solid black">
#         <td style="border: 1px solid black">
#             <p>Max Depth: 1</p>
#             <p>Bag Size: 5</p>
#         </td>
#         <td style="border: 1px solid black">
#             <table style="border: 1px solid black">
#                 <tr>
#                     <td style="border: 1px solid black">
#                         TP: {{ print(my_boosting_confusion_matrices[(1, 5)][1, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         FN: {{ print(my_boosting_confusion_matrices[(1, 5)][1, 0]) }}
#                     </td>
#                 </tr>
#                 <tr>
#                     <td style="border: 1px solid black">
#                         FP: {{ print(my_boosting_confusion_matrices[(1, 5)][0, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         TN: {{ print(my_boosting_confusion_matrices[(1, 5)][0, 0]) }}
#                     </td>
#                 </tr>
#             </table>
#             <p>Accuracy: {{ my_boosting_accuracies[(1, 5)] }}</p>
#             <p>Precision: {{ my_boosting_precisions[(1, 5)] }}</p>
#             <p>Recall: {{ my_boosting_recalls[(1, 5)] }}</p>
#         </td>
#         <td style="border: 1px solid black">
#             <table style="border: 1px solid black">
#                 <tr>
#                     <td style="border: 1px solid black">
#                         TP: {{ print(sk_boosting_confusion_matrices[(1, 5)][1, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         FN: {{ print(sk_boosting_confusion_matrices[(1, 5)][1, 0]) }}
#                     </td>
#                 </tr>
#                 <tr>
#                     <td style="border: 1px solid black">
#                         FP: {{ print(sk_boosting_confusion_matrices[(1, 5)][0, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         TN: {{ print(sk_boosting_confusion_matrices[(1, 5)][0, 0]) }}
#                     </td>
#                 </tr>
#             </table>
#             <p>Accuracy: {{ sk_boosting_accuracies[(1, 5)] }}</p>
#             <p>Precision: {{ sk_boosting_precisions[(1, 5)] }}</p>
#             <p>Recall: {{ sk_boosting_recalls[(1, 5)] }}</p>
#         </td>
#     </tr>
#     <tr style="border: 1px solid black">
#         <td style="border: 1px solid black">
#             <p>Max Depth: 1</p>
#             <p>Bag Size: 10</p>
#         </td>
#         <td style="border: 1px solid black">
#             <table style="border: 1px solid black">
#                 <tr>
#                     <td style="border: 1px solid black">
#                         TP: {{ print(my_boosting_confusion_matrices[(1, 10)][1, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         FN: {{ print(my_boosting_confusion_matrices[(1, 10)][1, 0]) }}
#                     </td>
#                 </tr>
#                 <tr>
#                     <td style="border: 1px solid black">
#                         FP: {{ print(my_boosting_confusion_matrices[(1, 10)][0, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         TN: {{ print(my_boosting_confusion_matrices[(1, 10)][0, 0]) }}
#                     </td>
#                 </tr>
#             </table>
#             <p>Accuracy: {{ my_boosting_accuracies[(1, 10)] }}</p>
#             <p>Precision: {{ my_boosting_precisions[(1, 10)] }}</p>
#             <p>Recall: {{ my_boosting_recalls[(1, 10)] }}</p>
#         </td>
#         <td style="border: 1px solid black">
#             <table style="border: 1px solid black">
#                 <tr>
#                     <td style="border: 1px solid black">
#                         TP: {{ print(sk_boosting_confusion_matrices[(1, 10)][1, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         FN: {{ print(sk_boosting_confusion_matrices[(1, 10)][1, 0]) }}
#                     </td>
#                 </tr>
#                 <tr>
#                     <td style="border: 1px solid black">
#                         FP: {{ print(sk_boosting_confusion_matrices[(1, 10)][0, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         TN: {{ print(sk_boosting_confusion_matrices[(1, 10)][0, 0]) }}
#                     </td>
#                 </tr>
#             </table>
#             <p>Accuracy: {{ sk_boosting_accuracies[(1, 10)] }}</p>
#             <p>Precision: {{ sk_boosting_precisions[(1, 10)] }}</p>
#             <p>Recall: {{ sk_boosting_recalls[(1, 10)] }}</p>
#         </td>
#     </tr>
#     <tr style="border: 1px solid black">
#         <td style="border: 1px solid black">
#             <p>Max Depth: 2</p>
#             <p>Bag Size: 5</p>
#         </td>
#         <td style="border: 1px solid black">
#             <table style="border: 1px solid black">
#                 <tr>
#                     <td style="border: 1px solid black">
#                         TP: {{ print(my_boosting_confusion_matrices[(2, 5)][1, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         FN: {{ print(my_boosting_confusion_matrices[(2, 5)][1, 0]) }}
#                     </td>
#                 </tr>
#                 <tr>
#                     <td style="border: 1px solid black">
#                         FP: {{ print(my_boosting_confusion_matrices[(2, 5)][0, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         TN: {{ print(my_boosting_confusion_matrices[(2, 5)][0, 0]) }}
#                     </td>
#                 </tr>
#             </table>
#             <p>Accuracy: {{ my_boosting_accuracies[(2, 5)] }}</p>
#             <p>Precision: {{ my_boosting_precisions[(2, 5)] }}</p>
#             <p>Recall: {{ my_boosting_recalls[(2, 5)] }}</p>
#         </td>
#         <td style="border: 1px solid black">
#             <table style="border: 1px solid black">
#                 <tr>
#                     <td style="border: 1px solid black">
#                         TP: {{ print(sk_boosting_confusion_matrices[(2, 5)][1, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         FN: {{ print(sk_boosting_confusion_matrices[(2, 5)][1, 0]) }}
#                     </td>
#                 </tr>
#                 <tr>
#                     <td style="border: 1px solid black">
#                         FP: {{ print(sk_boosting_confusion_matrices[(2, 5)][0, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         TN: {{ print(sk_boosting_confusion_matrices[(2, 5)][0, 0]) }}
#                     </td>
#                 </tr>
#             </table>
#             <p>Accuracy: {{ sk_boosting_accuracies[(2, 5)] }}</p>
#             <p>Precision: {{ sk_boosting_precisions[(2, 5)] }}</p>
#             <p>Recall: {{ sk_boosting_recalls[(2, 5)] }}</p>
#         </td>
#     </tr>
#     <tr style="border: 1px solid black">
#         <td style="border: 1px solid black">
#             <p>Max Depth: 2</p>
#             <p>Bag Size: 10</p>
#         </td>
#         <td style="border: 1px solid black">
#             <table style="border: 1px solid black">
#                 <tr>
#                     <td style="border: 1px solid black">
#                         TP: {{ print(my_boosting_confusion_matrices[(2, 10)][1, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         FN: {{ print(my_boosting_confusion_matrices[(2, 10)][1, 0]) }}
#                     </td>
#                 </tr>
#                 <tr>
#                     <td style="border: 1px solid black">
#                         FP: {{ print(my_boosting_confusion_matrices[(2, 10)][0, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         TN: {{ print(my_boosting_confusion_matrices[(2, 10)][0, 0]) }}
#                     </td>
#                 </tr>
#             </table>
#             <p>Accuracy: {{ my_boosting_accuracies[(2, 10)] }}</p>
#             <p>Precision: {{ my_boosting_precisions[(2, 10)] }}</p>
#             <p>Recall: {{ my_boosting_recalls[(2, 10)] }}</p>
#         </td>
#         <td style="border: 1px solid black">
#             <table style="border: 1px solid black">
#                 <tr>
#                     <td style="border: 1px solid black">
#                         TP: {{ print(sk_boosting_confusion_matrices[(2, 10)][1, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         FN: {{ print(sk_boosting_confusion_matrices[(2, 10)][1, 0]) }}
#                     </td>
#                 </tr>
#                 <tr>
#                     <td style="border: 1px solid black">
#                         FP: {{ print(sk_boosting_confusion_matrices[(2, 10)][0, 1]) }}
#                     </td>
#                     <td style="border: 1px solid black">
#                         TN: {{ print(sk_boosting_confusion_matrices[(2, 10)][0, 0]) }}
#                     </td>
#                 </tr>
#             </table>
#             <p>Accuracy: {{ sk_boosting_accuracies[(2, 10)] }}</p>
#             <p>Precision: {{ sk_boosting_precisions[(2, 10)] }}</p>
#             <p>Recall: {{ sk_boosting_recalls[(2, 10)] }}</p>
#         </td>
#     </tr>
# </table>
